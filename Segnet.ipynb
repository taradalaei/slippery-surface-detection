# %%
import zipfile
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import numpy as np

# %%
# !pip install gdown
import gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
file_id = "1KEwL97mJH-B1VTXAK4_WAOkE4kfCQlEB"
gdown.download(f"https://drive.google.com/uc?id={file_id}", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1KEwL97mJH-B1VTXAK4_WAOkE4kfCQlEB
# From (redirected): https://drive.google.com/uc?id=1KEwL97mJH-B1VTXAK4_WAOkE4kfCQlEB&confirm=t&uuid=6a24fa28-85b1-4b0e-be6d-8a4cf98a1f25
# To: /content/Copy of waterPuddle.zip
# 100%|██████████| 825M/825M [00:07<00:00, 113MB/s]
# 'Copy of waterPuddle.zip'

# %%
zip_path = "/content/Copy of waterPuddle.zip"
extract_path = "/content"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Check contents
os.listdir(extract_path)
# Out:
# ['.config', 'Copy of waterPuddle.zip', 'waterPuddle', 'sample_data']

# %%
import os

# Adjust path if needed
data_dir = "/content/waterPuddle"
for root, dirs, files in os.walk(data_dir):
    print(f"\n📂 Directory: {root}")
    for file in files[:5]:  # show up to 5 files per folder
        print("   └──", file)
# Out:
# 📂 Directory: /content/waterPuddle
#
# 📂 Directory: /content/waterPuddle/annotations
#
# 📂 Directory: /content/waterPuddle/annotations/6
#    └── img-000003381_0.png
#    └── img-000002112_0.png
#    └── img-000002112_4.png
#    └── img-000000803_3.png
#    └── img-000001783_3.png
#
# 📂 Directory: /content/waterPuddle/annotations/1
#    └── 110108_0.png
#    └── 052_0.png
#    └── 11087_0.png
#    └── 10086_0.png
#    └── 100110_3.png
#
# 📂 Directory: /content/waterPuddle/annotations/7
#    └── potholes-1-781x441_9.png
#    └── potholes-on-mumbai-goa-highway-to-be-fixed-by-september-5_2.png
#    └── img-000004471_3.png
#    └── img-000004242_0.png
#    └── img-000003421_2.png
#
# 📂 Directory: /content/waterPuddle/annotations/4
#    └── 6093_0.png
#    └── 51023_0.png
#    └── 630100_0.png
#    └── 5041_0.png
#    └── 6073_0.png
#
# 📂 Directory: /content/waterPuddle/annotations/2
#    └── 1564147103-Mumbai-potholes_17.png
#    └── 21025_1.png
#    └── 2051_0.png
#    └── 2005_5.png
#    └── 1564147103-Mumbai-potholes_0.png
#
# 📂 Directory: /content/waterPuddle/annotations/5
#    └── 7056_0.png
#    └── Potholes-Milton_3.png
#    └── img-000000301_4.png
#    └── img-000000608_1.png
#    └── 8053_1.png
#
# 📂 Directory: /content/waterPuddle/annotations/3
#    └── 220110_1.png
#    └── 2205_7.png
#    └── 2205_6.png
#    └── 22025_1.png
#    └── 21077_0.png
#
# 📂 Directory: /content/waterPuddle/imgs
#
# 📂 Directory: /content/waterPuddle/imgs/6
#    └── img-000002707.png
#    └── img-000002942.png
#    └── img-000000831.png
#    └── img-000002543.png
#    └── img-000002242.png
#
# 📂 Directory: /content/waterPuddle/imgs/1
#    └── 0108.jpg
#    └── 079.jpg
#    └── 030.jpg
#    └── 061.jpg
#    └── 065.jpg
#
# 📂 Directory: /content/waterPuddle/imgs/7
#    └── img-000003851.jpg
#    └── img-000004322.jpg
#    └── img-000005261.jpg
#    └── img-000004361.jpg
#    └── img-000004308.jpg
#
# 📂 Directory: /content/waterPuddle/imgs/4
#    └── 4066.jpg
#    └── 53023.jpg
#    └── 5022.jpg
#    └── 5061.jpg
#    └── 5053.jpg
#
# 📂 Directory: /content/waterPuddle/imgs/2
#    └── 1802.jpg
#    └── 17013.jpg
#    └── 20108.jpg
#    └── 20100.jpg
#    └── 2086.jpg
#
# 📂 Directory: /content/waterPuddle/imgs/5
#    └── Best-Pothole-Repair-Practices-In-Canada.jpg
#    └── 7040.jpg
#    └── 9097.jpg
#    └── 70108.jpg
#    └── 8057.jpg
#
# 📂 Directory: /content/waterPuddle/imgs/3
#    └── 27025.jpg
#    └── 21057.jpg
#    └── 23053.jpg
#    └── 230111.jpg
#    └── 25077.jpg

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
import matplotlib.pyplot as plt

def load_image_and_annotation(class_id, img_name=None):
    img_dir = f"/content/waterPuddle/imgs/{class_id}"
    ann_dir = f"/content/waterPuddle/annotations/{class_id}"

    # List files
    img_files = sorted(os.listdir(img_dir))
    ann_files = sorted(os.listdir(ann_dir))

    # Pick a specific file or the first one
    if img_name is None:
        img_name = img_files[0]

    # Try to find corresponding annotation
    base_name = os.path.splitext(img_name)[0]
    ann_match = [f for f in ann_files if base_name in f]

    if not ann_match:
        print(f"No annotation found for {img_name}")
        return

    img_path = os.path.join(img_dir, img_name)
    ann_path = os.path.join(ann_dir, ann_match[0])

    # Load
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    mask = cv2.imread(ann_path, cv2.IMREAD_GRAYSCALE)

    # Plot
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title(f"Image: {img_name}")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(mask, cmap='gray')
    plt.title(f"Annotation: {ann_match[0]}")
    plt.axis("off")
    plt.show()

# %%
load_image_and_annotation(class_id="7")

# %%
import os

imgs_dir = "/content/waterPuddle/imgs"
annotations_dir = "/content/waterPuddle/annotations"

print(f"{'Class':<6} | {'Images':<6} | {'Annotations':<11}")
print("-" * 32)

for class_id in sorted(os.listdir(imgs_dir)):
    class_img_path = os.path.join(imgs_dir, class_id)
    class_ann_path = os.path.join(annotations_dir, class_id)

    if not os.path.isdir(class_img_path):
        continue

    num_imgs = len([f for f in os.listdir(class_img_path) if f.endswith(('.jpg', '.png'))])
    num_anns = len([f for f in os.listdir(class_ann_path) if f.endswith('.png')]) if os.path.exists(class_ann_path) else 0

    print(f"{class_id:<6} | {num_imgs:<6} | {num_anns:<11}")
# Out:
# Class  | Images | Annotations
# --------------------------------
# 1      | 500    | 793
# 2      | 500    | 959
# 3      | 500    | 796
# 4      | 500    | 287
# 5      | 499    | 1813
# 6      | 486    | 1378
# 7      | 469    | 1203

# %%
# !ls train/annotations/ | wc -l
# Out:
# ls: cannot access 'train/annotations/': No such file or directory
# 0

# %%
extracted_path = "/content/"
train_path = "/content/train"
test_path = "/content/test"

# %%
os.makedirs(train_path, exist_ok=True)
os.makedirs(test_path, exist_ok=True)
os.makedirs(os.path.join(train_path,"imgs"), exist_ok=True)
os.makedirs(os.path.join(train_path,"annotations"),  exist_ok=True)
os.makedirs(os.path.join(test_path,"imgs"),  exist_ok=True)
os.makedirs(os.path.join(test_path,"annotations"),  exist_ok=True)

# %%
import os
import random
import shutil
import cv2 as cv

# List all subdirectories in 'imgs' directory
img_subfolders = [f for f in os.listdir(os.path.join(extracted_path, 'waterPuddle/imgs')) if os.path.isdir(os.path.join(extracted_path, 'waterPuddle/imgs', f))]

# Iterate over each subfolder
for subfolder in img_subfolders:
    subfolder_path = os.path.join(extracted_path, 'waterPuddle/imgs', subfolder)
    print("subfolder_path",subfolder_path)
    # List all image files in the current subfolder
    imgs_files = [f for f in os.listdir(subfolder_path) if (f.endswith('.jpg') or f.endswith('.png'))]
    # Shuffle the files for randomness before splitting
    random.shuffle(imgs_files)
    print('all images',len(imgs_files))
    # Split the data
    split_index = int(0.8 * len(imgs_files))
    train_imgs = imgs_files[:split_index]
    test_imgs = imgs_files[split_index:]
    print('train_imgs',len(train_imgs))
    print('test_imgs',len(test_imgs))

    # Merge masks and move files to train folder
    for img in train_imgs:
      if img.endswith('.jpg'):
        annotation_file = os.path.join(extracted_path, 'waterPuddle/annotations', subfolder, img.replace('.jpg', '_0.png'))
      elif img.endswith('.png'):
        annotation_file = os.path.join(extracted_path, 'waterPuddle/annotations', subfolder, img.replace('.png', '_0.png'))
      i = 0 #index of annotation
      # Check if the annotation file exist
      print('img',img)
      label_path = annotation_file
      print('annotation_file',annotation_file)

      while os.path.exists(label_path):
        print('label_path',label_path)

        label_path = "%s_%d.png" % (annotation_file.rsplit("_0")[0],i+1)
        if i == 0 and os.path.exists(label_path):
          print('first mask')
          mask = cv.imread(annotation_file,1)
          i = i +1
        elif i != 0 and os.path.exists(label_path) :
          print(f'{i}th mask')
          label = cv.imread(label_path,1)
          mask = cv.bitwise_or(label, mask)
          i = i +1
        elif i== 0 and not os.path.exists(label_path):
          print('only one mask')
          mask = cv.imread(annotation_file,1)
          img_path = os.path.join(train_path, 'imgs', img)
          shutil.move(os.path.join(subfolder_path, img), img_path)
          img = img.rsplit('.')[0]
          print('img',img)
          annotations_path = os.path.join(train_path, 'annotations', img+'.png')
          print("img_path",img_path)
          print("annotations_path",annotations_path)
          cv.imwrite(annotations_path,mask)
          print('saved-train')

        elif i!=0 and not os.path.exists(label_path) :
          img_path = os.path.join(train_path, 'imgs', img)
          shutil.move(os.path.join(subfolder_path, img), img_path)
          img = img.rsplit('.')[0]
          print('img',img)
          annotations_path = os.path.join(train_path, 'annotations', img+'.png')
          print("img_path",img_path)
          print("annotations_path",annotations_path)
          cv.imwrite(annotations_path,mask)
          print('saved-train')


    # Merge masks and move files to train folder
    for img in test_imgs:
      if img.endswith('.jpg'):
        annotation_file = os.path.join(extracted_path, 'waterPuddle/annotations', subfolder, img.replace('.jpg', '_0.png'))
      elif img.endswith('.png'):
        annotation_file = os.path.join(extracted_path, 'waterPuddle/annotations', subfolder, img.replace('.png', '_0.png'))
      i = 0 #index of annotation
      # Check if the annotation file exist
      print('img',img)
      label_path = annotation_file
      print('annotation_file',annotation_file)

      while os.path.exists(label_path):
        print('label_path',label_path)

        label_path = "%s_%d.png" % (annotation_file.rsplit("_0")[0],i+1)
        if i == 0 and os.path.exists(label_path):
          print('first mask')
          mask = cv.imread(annotation_file,1)
          i = i +1
        elif i != 0 and os.path.exists(label_path) :
          print(f'{i}th mask')
          label = cv.imread(label_path,1)
          mask = cv.bitwise_or(label, mask)
          i = i +1
        elif i== 0 and not os.path.exists(label_path):
          print('only one mask')
          mask = cv.imread(annotation_file,1)
          img_path = os.path.join(test_path, 'imgs', img)
          shutil.move(os.path.join(subfolder_path, img), img_path)
          img = img.rsplit('.')[0]
          print('img',img)
          annotations_path = os.path.join(test_path, 'annotations', img+'.png')
          print("img_path",img_path)
          print("annotations_path",annotations_path)
          cv.imwrite(annotations_path,mask)
          print('saved-test')

        elif i!=0 and not os.path.exists(label_path) :
          img_path = os.path.join(test_path, 'imgs', img)
          shutil.move(os.path.join(subfolder_path, img), img_path)
          img = img.rsplit('.')[0]
          print('img',img)
          annotations_path = os.path.join(test_path, 'annotations', img+'.png')
          print("img_path",img_path)
          print("annotations_path",annotations_path)
          cv.imwrite(annotations_path,mask)
          print('saved-test')
# Out:
# Streaming output truncated to the last 5000 lines.
# img 8051.jpg
# annotation_file /content/waterPuddle/annotations/5/8051_0.png
# label_path /content/waterPuddle/annotations/5/8051_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/8051_1.png
# img 8051
# img_path /content/test/imgs/8051.jpg
# annotations_path /content/test/annotations/8051.png
# saved-test
# img 7013.jpg
# annotation_file /content/waterPuddle/annotations/5/7013_0.png
# img 906.jpg
# annotation_file /content/waterPuddle/annotations/5/906_0.png
# label_path /content/waterPuddle/annotations/5/906_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/906_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/906_2.png
# img 906
# img_path /content/test/imgs/906.jpg
# annotations_path /content/test/annotations/906.png
# saved-test
# img 9059.jpg
# annotation_file /content/waterPuddle/annotations/5/9059_0.png
# label_path /content/waterPuddle/annotations/5/9059_0.png
# only one mask
# img 9059
# img_path /content/test/imgs/9059.jpg
# annotations_path /content/test/annotations/9059.png
# saved-test
# img 9047.jpg
# annotation_file /content/waterPuddle/annotations/5/9047_0.png
# label_path /content/waterPuddle/annotations/5/9047_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/9047_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/9047_2.png
# img 9047
# img_path /content/test/imgs/9047.jpg
# annotations_path /content/test/annotations/9047.png
# saved-test
# img b499cri8-mumbai-rains-625x300-06-July-22.jpg
# annotation_file /content/waterPuddle/annotations/5/b499cri8-mumbai-rains-625x300-06-July-22_0.png
# label_path /content/waterPuddle/annotations/5/b499cri8-mumbai-rains-625x300-06-July-22_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/b499cri8-mumbai-rains-625x300-06-July-22_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/b499cri8-mumbai-rains-625x300-06-July-22_2.png
# img b499cri8-mumbai-rains-625x300-06-July-22
# img_path /content/test/imgs/b499cri8-mumbai-rains-625x300-06-July-22.jpg
# annotations_path /content/test/annotations/b499cri8-mumbai-rains-625x300-06-July-22.png
# saved-test
# img 7093.jpg
# annotation_file /content/waterPuddle/annotations/5/7093_0.png
# label_path /content/waterPuddle/annotations/5/7093_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/7093_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/7093_2.png
# img 7093
# img_path /content/test/imgs/7093.jpg
# annotations_path /content/test/annotations/7093.png
# saved-test
# img 9093.jpg
# annotation_file /content/waterPuddle/annotations/5/9093_0.png
# label_path /content/waterPuddle/annotations/5/9093_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/9093_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/9093_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/9093_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/9093_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/9093_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/9093_6.png
# img 9093
# img_path /content/test/imgs/9093.jpg
# annotations_path /content/test/annotations/9093.png
# saved-test
# img 9052.jpg
# annotation_file /content/waterPuddle/annotations/5/9052_0.png
# label_path /content/waterPuddle/annotations/5/9052_0.png
# only one mask
# img 9052
# img_path /content/test/imgs/9052.jpg
# annotations_path /content/test/annotations/9052.png
# saved-test
# img file-16089009.jpg
# annotation_file /content/waterPuddle/annotations/5/file-16089009_0.png
# label_path /content/waterPuddle/annotations/5/file-16089009_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/file-16089009_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/file-16089009_2.png
# img file-16089009
# img_path /content/test/imgs/file-16089009.jpg
# annotations_path /content/test/annotations/file-16089009.png
# saved-test
# img 8067.jpg
# annotation_file /content/waterPuddle/annotations/5/8067_0.png
# label_path /content/waterPuddle/annotations/5/8067_0.png
# only one mask
# img 8067
# img_path /content/test/imgs/8067.jpg
# annotations_path /content/test/annotations/8067.png
# saved-test
# img img-000000191.png
# annotation_file /content/waterPuddle/annotations/5/img-000000191_0.png
# label_path /content/waterPuddle/annotations/5/img-000000191_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000191_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/img-000000191_9.png
# img img-000000191
# img_path /content/test/imgs/img-000000191.png
# annotations_path /content/test/annotations/img-000000191.png
# saved-test
# img 8040.jpg
# annotation_file /content/waterPuddle/annotations/5/8040_0.png
# label_path /content/waterPuddle/annotations/5/8040_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/8040_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/8040_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/8040_3.png
# img 8040
# img_path /content/test/imgs/8040.jpg
# annotations_path /content/test/annotations/8040.png
# saved-test
# img 7026.jpg
# annotation_file /content/waterPuddle/annotations/5/7026_0.png
# label_path /content/waterPuddle/annotations/5/7026_0.png
# only one mask
# img 7026
# img_path /content/test/imgs/7026.jpg
# annotations_path /content/test/annotations/7026.png
# saved-test
# img 805.jpg
# annotation_file /content/waterPuddle/annotations/5/805_0.png
# label_path /content/waterPuddle/annotations/5/805_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/805_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/805_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/805_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/805_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/805_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/805_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/805_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/805_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/805_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/805_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/805_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/805_12.png
# 12th mask
# label_path /content/waterPuddle/annotations/5/805_13.png
# 13th mask
# label_path /content/waterPuddle/annotations/5/805_14.png
# 14th mask
# label_path /content/waterPuddle/annotations/5/805_15.png
# img 805
# img_path /content/test/imgs/805.jpg
# annotations_path /content/test/annotations/805.png
# saved-test
# img -POTHOLE-15JULY20-BLSONI-01.jpg
# annotation_file /content/waterPuddle/annotations/5/-POTHOLE-15JULY20-BLSONI-01_0.png
# label_path /content/waterPuddle/annotations/5/-POTHOLE-15JULY20-BLSONI-01_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/-POTHOLE-15JULY20-BLSONI-01_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/-POTHOLE-15JULY20-BLSONI-01_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/-POTHOLE-15JULY20-BLSONI-01_3.png
# img -POTHOLE-15JULY20-BLSONI-01
# img_path /content/test/imgs/-POTHOLE-15JULY20-BLSONI-01.jpg
# annotations_path /content/test/annotations/-POTHOLE-15JULY20-BLSONI-01.png
# saved-test
# img 80108.jpg
# annotation_file /content/waterPuddle/annotations/5/80108_0.png
# label_path /content/waterPuddle/annotations/5/80108_0.png
# only one mask
# img 80108
# img_path /content/test/imgs/80108.jpg
# annotations_path /content/test/annotations/80108.png
# saved-test
# img Potholes.jpg
# annotation_file /content/waterPuddle/annotations/5/Potholes_0.png
# label_path /content/waterPuddle/annotations/5/Potholes_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/Potholes_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/Potholes_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/Potholes_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/Potholes_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/Potholes_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/Potholes_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/Potholes_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/Potholes_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/Potholes_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/Potholes_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/Potholes_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/Potholes_12.png
# 12th mask
# label_path /content/waterPuddle/annotations/5/Potholes_13.png
# img Potholes
# img_path /content/test/imgs/Potholes.jpg
# annotations_path /content/test/annotations/Potholes.png
# saved-test
# img img-000000541.png
# annotation_file /content/waterPuddle/annotations/5/img-000000541_0.png
# img 9026.jpg
# annotation_file /content/waterPuddle/annotations/5/9026_0.png
# label_path /content/waterPuddle/annotations/5/9026_0.png
# only one mask
# img 9026
# img_path /content/test/imgs/9026.jpg
# annotations_path /content/test/annotations/9026.png
# saved-test
# img 8066.jpg
# annotation_file /content/waterPuddle/annotations/5/8066_0.png
# label_path /content/waterPuddle/annotations/5/8066_0.png
# only one mask
# img 8066
# img_path /content/test/imgs/8066.jpg
# annotations_path /content/test/annotations/8066.png
# saved-test
# img 9083.jpg
# annotation_file /content/waterPuddle/annotations/5/9083_0.png
# img close-up-photo-flooded-floor-kitchen-water-leak-broken-dishw.jpg
# annotation_file /content/waterPuddle/annotations/5/close-up-photo-flooded-floor-kitchen-water-leak-broken-dishw_0.png
# label_path /content/waterPuddle/annotations/5/close-up-photo-flooded-floor-kitchen-water-leak-broken-dishw_0.png
# only one mask
# img close-up-photo-flooded-floor-kitchen-water-leak-broken-dishw
# img_path /content/test/imgs/close-up-photo-flooded-floor-kitchen-water-leak-broken-dishw.jpg
# annotations_path /content/test/annotations/close-up-photo-flooded-floor-kitchen-water-leak-broken-dishw.png
# saved-test
# img IMG-MDA100474-1600px.jpg
# annotation_file /content/waterPuddle/annotations/5/IMG-MDA100474-1600px_0.png
# label_path /content/waterPuddle/annotations/5/IMG-MDA100474-1600px_0.png
# only one mask
# img IMG-MDA100474-1600px
# img_path /content/test/imgs/IMG-MDA100474-1600px.jpg
# annotations_path /content/test/annotations/IMG-MDA100474-1600px.png
# saved-test
# img 70105.jpg
# annotation_file /content/waterPuddle/annotations/5/70105_0.png
# label_path /content/waterPuddle/annotations/5/70105_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/70105_1.png
# img 70105
# img_path /content/test/imgs/70105.jpg
# annotations_path /content/test/annotations/70105.png
# saved-test
# img 7014.jpg
# annotation_file /content/waterPuddle/annotations/5/7014_0.png
# label_path /content/waterPuddle/annotations/5/7014_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/7014_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/7014_2.png
# img 7014
# img_path /content/test/imgs/7014.jpg
# annotations_path /content/test/annotations/7014.png
# saved-test
# img img-000000412.png
# annotation_file /content/waterPuddle/annotations/5/img-000000412_0.png
# label_path /content/waterPuddle/annotations/5/img-000000412_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000412_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000412_2.png
# img img-000000412
# img_path /content/test/imgs/img-000000412.png
# annotations_path /content/test/annotations/img-000000412.png
# saved-test
# img img-000000582.png
# annotation_file /content/waterPuddle/annotations/5/img-000000582_0.png
# label_path /content/waterPuddle/annotations/5/img-000000582_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000582_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000582_2.png
# img img-000000582
# img_path /content/test/imgs/img-000000582.png
# annotations_path /content/test/annotations/img-000000582.png
# saved-test
# img 70111.jpg
# annotation_file /content/waterPuddle/annotations/5/70111_0.png
# label_path /content/waterPuddle/annotations/5/70111_0.png
# only one mask
# img 70111
# img_path /content/test/imgs/70111.jpg
# annotations_path /content/test/annotations/70111.png
# saved-test
# img img-000000171.png
# annotation_file /content/waterPuddle/annotations/5/img-000000171_0.png
# label_path /content/waterPuddle/annotations/5/img-000000171_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000171_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/img-000000171_8.png
# img img-000000171
# img_path /content/test/imgs/img-000000171.png
# annotations_path /content/test/annotations/img-000000171.png
# saved-test
# img img-000000453.png
# annotation_file /content/waterPuddle/annotations/5/img-000000453_0.png
# label_path /content/waterPuddle/annotations/5/img-000000453_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000453_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000453_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000453_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000453_4.png
# img img-000000453
# img_path /content/test/imgs/img-000000453.png
# annotations_path /content/test/annotations/img-000000453.png
# saved-test
# img img-000000709.png
# annotation_file /content/waterPuddle/annotations/5/img-000000709_0.png
# label_path /content/waterPuddle/annotations/5/img-000000709_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000709_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000709_2.png
# img img-000000709
# img_path /content/test/imgs/img-000000709.png
# annotations_path /content/test/annotations/img-000000709.png
# saved-test
# img e568dab8-bc81-45e4-8256-d3ce29b9a0b2-large16x9-pothole6.jpg
# annotation_file /content/waterPuddle/annotations/5/e568dab8-bc81-45e4-8256-d3ce29b9a0b2-large16x9-pothole6_0.png
# img 92710893.jpg
# annotation_file /content/waterPuddle/annotations/5/92710893_0.png
# label_path /content/waterPuddle/annotations/5/92710893_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/92710893_1.png
# img 92710893
# img_path /content/test/imgs/92710893.jpg
# annotations_path /content/test/annotations/92710893.png
# saved-test
# img 704719-pothole.jpg
# annotation_file /content/waterPuddle/annotations/5/704719-pothole_0.png
# label_path /content/waterPuddle/annotations/5/704719-pothole_0.png
# only one mask
# img 704719-pothole
# img_path /content/test/imgs/704719-pothole.jpg
# annotations_path /content/test/annotations/704719-pothole.png
# saved-test
# img 9034.jpg
# annotation_file /content/waterPuddle/annotations/5/9034_0.png
# label_path /content/waterPuddle/annotations/5/9034_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/9034_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/9034_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/9034_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/9034_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/9034_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/9034_6.png
# img 9034
# img_path /content/test/imgs/9034.jpg
# annotations_path /content/test/annotations/9034.png
# saved-test
# img 8046.jpg
# annotation_file /content/waterPuddle/annotations/5/8046_0.png
# label_path /content/waterPuddle/annotations/5/8046_0.png
# only one mask
# img 8046
# img_path /content/test/imgs/8046.jpg
# annotations_path /content/test/annotations/8046.png
# saved-test
# img edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492.jpg
# annotation_file /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_0.png
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_12.png
# 12th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_13.png
# 13th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_14.png
# 14th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_15.png
# 15th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_16.png
# 16th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_17.png
# 17th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_18.png
# 18th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_19.png
# 19th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_20.png
# 20th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_21.png
# 21th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_22.png
# 22th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_23.png
# 23th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_24.png
# 24th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_25.png
# 25th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_26.png
# 26th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_27.png
# 27th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_28.png
# 28th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_29.png
# 29th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_30.png
# 30th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_31.png
# 31th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_32.png
# 32th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_33.png
# 33th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_34.png
# 34th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_35.png
# 35th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_36.png
# 36th mask
# label_path /content/waterPuddle/annotations/5/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492_37.png
# img edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492
# img_path /content/test/imgs/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492.jpg
# annotations_path /content/test/annotations/edaa8486-2076-11ec-a1d1-084c70c8551e-1632845638492.png
# saved-test
# img 8021.jpg
# annotation_file /content/waterPuddle/annotations/5/8021_0.png
# label_path /content/waterPuddle/annotations/5/8021_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/8021_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/8021_2.png
# img 8021
# img_path /content/test/imgs/8021.jpg
# annotations_path /content/test/annotations/8021.png
# saved-test
# img img-000000691.png
# annotation_file /content/waterPuddle/annotations/5/img-000000691_0.png
# img 7092.jpg
# annotation_file /content/waterPuddle/annotations/5/7092_0.png
# label_path /content/waterPuddle/annotations/5/7092_0.png
# only one mask
# img 7092
# img_path /content/test/imgs/7092.jpg
# annotations_path /content/test/annotations/7092.png
# saved-test
# img img-000000742.png
# annotation_file /content/waterPuddle/annotations/5/img-000000742_0.png
# label_path /content/waterPuddle/annotations/5/img-000000742_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000742_1.png
# img img-000000742
# img_path /content/test/imgs/img-000000742.png
# annotations_path /content/test/annotations/img-000000742.png
# saved-test
# img csm-191016-HOME-Building-350x350-3634c2bec0.jpg
# annotation_file /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_0.png
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_12.png
# 12th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_13.png
# 13th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_14.png
# 14th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_15.png
# 15th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_16.png
# 16th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_17.png
# 17th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_18.png
# 18th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_19.png
# 19th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_20.png
# 20th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_21.png
# 21th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_22.png
# 22th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_23.png
# 23th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_24.png
# 24th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_25.png
# 25th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_26.png
# 26th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_27.png
# 27th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_28.png
# 28th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_29.png
# 29th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_30.png
# 30th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_31.png
# 31th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_32.png
# 32th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_33.png
# 33th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_34.png
# 34th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_35.png
# 35th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_36.png
# 36th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_37.png
# 37th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_38.png
# 38th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_39.png
# 39th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_40.png
# 40th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_41.png
# 41th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_42.png
# 42th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_43.png
# 43th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_44.png
# 44th mask
# label_path /content/waterPuddle/annotations/5/csm-191016-HOME-Building-350x350-3634c2bec0_45.png
# img csm-191016-HOME-Building-350x350-3634c2bec0
# img_path /content/test/imgs/csm-191016-HOME-Building-350x350-3634c2bec0.jpg
# annotations_path /content/test/annotations/csm-191016-HOME-Building-350x350-3634c2bec0.png
# saved-test
# img gravel-driveway-pothole-repair.jpg
# annotation_file /content/waterPuddle/annotations/5/gravel-driveway-pothole-repair_0.png
# label_path /content/waterPuddle/annotations/5/gravel-driveway-pothole-repair_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/gravel-driveway-pothole-repair_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/gravel-driveway-pothole-repair_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/gravel-driveway-pothole-repair_3.png
# img gravel-driveway-pothole-repair
# img_path /content/test/imgs/gravel-driveway-pothole-repair.jpg
# annotations_path /content/test/annotations/gravel-driveway-pothole-repair.png
# saved-test
# img img-000000702.png
# annotation_file /content/waterPuddle/annotations/5/img-000000702_0.png
# label_path /content/waterPuddle/annotations/5/img-000000702_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000702_1.png
# img img-000000702
# img_path /content/test/imgs/img-000000702.png
# annotations_path /content/test/annotations/img-000000702.png
# saved-test
# img img-000000231.png
# annotation_file /content/waterPuddle/annotations/5/img-000000231_0.png
# label_path /content/waterPuddle/annotations/5/img-000000231_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000231_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/img-000000231_10.png
# img img-000000231
# img_path /content/test/imgs/img-000000231.png
# annotations_path /content/test/annotations/img-000000231.png
# saved-test
# img img-000000071.png
# annotation_file /content/waterPuddle/annotations/5/img-000000071_0.png
# label_path /content/waterPuddle/annotations/5/img-000000071_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000071_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/img-000000071_8.png
# img img-000000071
# img_path /content/test/imgs/img-000000071.png
# annotations_path /content/test/annotations/img-000000071.png
# saved-test
# img 70102.jpg
# annotation_file /content/waterPuddle/annotations/5/70102_0.png
# label_path /content/waterPuddle/annotations/5/70102_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/70102_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/70102_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/70102_3.png
# img 70102
# img_path /content/test/imgs/70102.jpg
# annotations_path /content/test/annotations/70102.png
# saved-test
# img human-767017-1920.jpg
# annotation_file /content/waterPuddle/annotations/5/human-767017-1920_0.png
# label_path /content/waterPuddle/annotations/5/human-767017-1920_0.png
# only one mask
# img human-767017-1920
# img_path /content/test/imgs/human-767017-1920.jpg
# annotations_path /content/test/annotations/human-767017-1920.png
# saved-test
# img img-000000409.png
# annotation_file /content/waterPuddle/annotations/5/img-000000409_0.png
# label_path /content/waterPuddle/annotations/5/img-000000409_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000409_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000409_2.png
# img img-000000409
# img_path /content/test/imgs/img-000000409.png
# annotations_path /content/test/annotations/img-000000409.png
# saved-test
# img 9013.jpg
# annotation_file /content/waterPuddle/annotations/5/9013_0.png
# label_path /content/waterPuddle/annotations/5/9013_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/9013_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/9013_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/9013_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/9013_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/9013_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/9013_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/9013_7.png
# img 9013
# img_path /content/test/imgs/9013.jpg
# annotations_path /content/test/annotations/9013.png
# saved-test
# img 80102.jpg
# annotation_file /content/waterPuddle/annotations/5/80102_0.png
# label_path /content/waterPuddle/annotations/5/80102_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/80102_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/80102_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/80102_3.png
# img 80102
# img_path /content/test/imgs/80102.jpg
# annotations_path /content/test/annotations/80102.png
# saved-test
# img img-000000402.png
# annotation_file /content/waterPuddle/annotations/5/img-000000402_0.png
# label_path /content/waterPuddle/annotations/5/img-000000402_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000402_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000402_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000402_3.png
# img img-000000402
# img_path /content/test/imgs/img-000000402.png
# annotations_path /content/test/annotations/img-000000402.png
# saved-test
# img 8045.jpg
# annotation_file /content/waterPuddle/annotations/5/8045_0.png
# label_path /content/waterPuddle/annotations/5/8045_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/8045_1.png
# img 8045
# img_path /content/test/imgs/8045.jpg
# annotations_path /content/test/annotations/8045.png
# saved-test
# img 7048.jpg
# annotation_file /content/waterPuddle/annotations/5/7048_0.png
# label_path /content/waterPuddle/annotations/5/7048_0.png
# only one mask
# img 7048
# img_path /content/test/imgs/7048.jpg
# annotations_path /content/test/annotations/7048.png
# saved-test
# img 90110.jpg
# annotation_file /content/waterPuddle/annotations/5/90110_0.png
# label_path /content/waterPuddle/annotations/5/90110_0.png
# only one mask
# img 90110
# img_path /content/test/imgs/90110.jpg
# annotations_path /content/test/annotations/90110.png
# saved-test
# img 9090.jpg
# annotation_file /content/waterPuddle/annotations/5/9090_0.png
# img OpIndia-P4-37.jpg
# annotation_file /content/waterPuddle/annotations/5/OpIndia-P4-37_0.png
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_12.png
# 12th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_13.png
# 13th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_14.png
# 14th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_15.png
# 15th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_16.png
# 16th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_17.png
# 17th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_18.png
# 18th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_19.png
# 19th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_20.png
# 20th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_21.png
# 21th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_22.png
# 22th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_23.png
# 23th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_24.png
# 24th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_25.png
# 25th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_26.png
# 26th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_27.png
# 27th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_28.png
# 28th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_29.png
# 29th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_30.png
# 30th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_31.png
# 31th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_32.png
# 32th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_33.png
# 33th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_34.png
# 34th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_35.png
# 35th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_36.png
# 36th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_37.png
# 37th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_38.png
# 38th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_39.png
# 39th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_40.png
# 40th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_41.png
# 41th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_42.png
# 42th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_43.png
# 43th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_44.png
# 44th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_45.png
# 45th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_46.png
# 46th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_47.png
# 47th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_48.png
# 48th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_49.png
# 49th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_50.png
# 50th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_51.png
# 51th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_52.png
# 52th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_53.png
# 53th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_54.png
# 54th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_55.png
# 55th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_56.png
# 56th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_57.png
# 57th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_58.png
# 58th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_59.png
# 59th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_60.png
# 60th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_61.png
# 61th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_62.png
# 62th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_63.png
# 63th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_64.png
# 64th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_65.png
# 65th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_66.png
# 66th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_67.png
# 67th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_68.png
# 68th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_69.png
# 69th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_70.png
# 70th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_71.png
# 71th mask
# label_path /content/waterPuddle/annotations/5/OpIndia-P4-37_72.png
# img OpIndia-P4-37
# img_path /content/test/imgs/OpIndia-P4-37.jpg
# annotations_path /content/test/annotations/OpIndia-P4-37.png
# saved-test
# img img-000000321.png
# annotation_file /content/waterPuddle/annotations/5/img-000000321_0.png
# label_path /content/waterPuddle/annotations/5/img-000000321_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000321_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000321_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000321_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000321_4.png
# img img-000000321
# img_path /content/test/imgs/img-000000321.png
# annotations_path /content/test/annotations/img-000000321.png
# saved-test
# img 7088.jpg
# annotation_file /content/waterPuddle/annotations/5/7088_0.png
# img Pothole-Twitter.png
# annotation_file /content/waterPuddle/annotations/5/Pothole-Twitter_0.png
# label_path /content/waterPuddle/annotations/5/Pothole-Twitter_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/Pothole-Twitter_1.png
# img Pothole-Twitter
# img_path /content/test/imgs/Pothole-Twitter.png
# annotations_path /content/test/annotations/Pothole-Twitter.png
# saved-test
# img 7037.jpg
# annotation_file /content/waterPuddle/annotations/5/7037_0.png
# label_path /content/waterPuddle/annotations/5/7037_0.png
# only one mask
# img 7037
# img_path /content/test/imgs/7037.jpg
# annotations_path /content/test/annotations/7037.png
# saved-test
# img img-000000331.png
# annotation_file /content/waterPuddle/annotations/5/img-000000331_0.png
# label_path /content/waterPuddle/annotations/5/img-000000331_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000331_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000331_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000331_3.png
# img img-000000331
# img_path /content/test/imgs/img-000000331.png
# annotations_path /content/test/annotations/img-000000331.png
# saved-test
# img HD-wallpaper-puddle-foliage-rain-wet-asphalt.jpg
# annotation_file /content/waterPuddle/annotations/5/HD-wallpaper-puddle-foliage-rain-wet-asphalt_0.png
# label_path /content/waterPuddle/annotations/5/HD-wallpaper-puddle-foliage-rain-wet-asphalt_0.png
# only one mask
# img HD-wallpaper-puddle-foliage-rain-wet-asphalt
# img_path /content/test/imgs/HD-wallpaper-puddle-foliage-rain-wet-asphalt.jpg
# annotations_path /content/test/annotations/HD-wallpaper-puddle-foliage-rain-wet-asphalt.png
# saved-test
# img bad pothole.png
# annotation_file /content/waterPuddle/annotations/5/bad pothole_0.png
# label_path /content/waterPuddle/annotations/5/bad pothole_0.png
# only one mask
# img bad pothole
# img_path /content/test/imgs/bad pothole.png
# annotations_path /content/test/annotations/bad pothole.png
# saved-test
# img img-000000361.png
# annotation_file /content/waterPuddle/annotations/5/img-000000361_0.png
# label_path /content/waterPuddle/annotations/5/img-000000361_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000361_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000361_2.png
# img img-000000361
# img_path /content/test/imgs/img-000000361.png
# annotations_path /content/test/annotations/img-000000361.png
# saved-test
# img 7050.jpg
# annotation_file /content/waterPuddle/annotations/5/7050_0.png
# label_path /content/waterPuddle/annotations/5/7050_0.png
# only one mask
# img 7050
# img_path /content/test/imgs/7050.jpg
# annotations_path /content/test/annotations/7050.png
# saved-test
# img img-000000508.png
# annotation_file /content/waterPuddle/annotations/5/img-000000508_0.png
# label_path /content/waterPuddle/annotations/5/img-000000508_0.png
# only one mask
# img img-000000508
# img_path /content/test/imgs/img-000000508.png
# annotations_path /content/test/annotations/img-000000508.png
# saved-test
# img 7065.jpg
# annotation_file /content/waterPuddle/annotations/5/7065_0.png
# label_path /content/waterPuddle/annotations/5/7065_0.png
# only one mask
# img 7065
# img_path /content/test/imgs/7065.jpg
# annotations_path /content/test/annotations/7065.png
# saved-test
# img img-000000161.png
# annotation_file /content/waterPuddle/annotations/5/img-000000161_0.png
# label_path /content/waterPuddle/annotations/5/img-000000161_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/img-000000161_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/img-000000161_12.png
# img img-000000161
# img_path /content/test/imgs/img-000000161.png
# annotations_path /content/test/annotations/img-000000161.png
# saved-test
# img 903.jpg
# annotation_file /content/waterPuddle/annotations/5/903_0.png
# label_path /content/waterPuddle/annotations/5/903_0.png
# only one mask
# img 903
# img_path /content/test/imgs/903.jpg
# annotations_path /content/test/annotations/903.png
# saved-test
# img img-000000561.png
# annotation_file /content/waterPuddle/annotations/5/img-000000561_0.png
# img 9031.jpg
# annotation_file /content/waterPuddle/annotations/5/9031_0.png
# label_path /content/waterPuddle/annotations/5/9031_0.png
# only one mask
# img 9031
# img_path /content/test/imgs/9031.jpg
# annotations_path /content/test/annotations/9031.png
# saved-test
# img GettyImages-931012328-1080x675.jpg
# annotation_file /content/waterPuddle/annotations/5/GettyImages-931012328-1080x675_0.png
# label_path /content/waterPuddle/annotations/5/GettyImages-931012328-1080x675_0.png
# only one mask
# img GettyImages-931012328-1080x675
# img_path /content/test/imgs/GettyImages-931012328-1080x675.jpg
# annotations_path /content/test/annotations/GettyImages-931012328-1080x675.png
# saved-test
# img csm-csm-osb-boards-swisskrono-960-300-6c86fb5987.jpg
# annotation_file /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_0.png
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_0.png
# first mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_3.png
# 3th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_4.png
# 4th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_5.png
# 5th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_6.png
# 6th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_7.png
# 7th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_8.png
# 8th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_9.png
# 9th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_10.png
# 10th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_11.png
# 11th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_12.png
# 12th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_13.png
# 13th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_14.png
# 14th mask
# label_path /content/waterPuddle/annotations/5/csm-csm-osb-boards-swisskrono-960-300-6c86fb5987_15.png
# 15th mask
# ...
# annotations_path /content/test/annotations/260110.png
# saved-test
# img 22091.jpg
# annotation_file /content/waterPuddle/annotations/3/22091_0.png
# label_path /content/waterPuddle/annotations/3/22091_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/22091_1.png
# img 22091
# img_path /content/test/imgs/22091.jpg
# annotations_path /content/test/annotations/22091.png
# saved-test
# img 22095.jpg
# annotation_file /content/waterPuddle/annotations/3/22095_0.png
# label_path /content/waterPuddle/annotations/3/22095_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/22095_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/3/22095_2.png
# img 22095
# img_path /content/test/imgs/22095.jpg
# annotations_path /content/test/annotations/22095.png
# saved-test
# img 23075.jpg
# annotation_file /content/waterPuddle/annotations/3/23075_0.png
# label_path /content/waterPuddle/annotations/3/23075_0.png
# only one mask
# img 23075
# img_path /content/test/imgs/23075.jpg
# annotations_path /content/test/annotations/23075.png
# saved-test
# img 23035.jpg
# annotation_file /content/waterPuddle/annotations/3/23035_0.png
# label_path /content/waterPuddle/annotations/3/23035_0.png
# only one mask
# img 23035
# img_path /content/test/imgs/23035.jpg
# annotations_path /content/test/annotations/23035.png
# saved-test
# img 33086.jpg
# annotation_file /content/waterPuddle/annotations/3/33086_0.png
# label_path /content/waterPuddle/annotations/3/33086_0.png
# only one mask
# img 33086
# img_path /content/test/imgs/33086.jpg
# annotations_path /content/test/annotations/33086.png
# saved-test
# img 21069.jpg
# annotation_file /content/waterPuddle/annotations/3/21069_0.png
# label_path /content/waterPuddle/annotations/3/21069_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/21069_1.png
# img 21069
# img_path /content/test/imgs/21069.jpg
# annotations_path /content/test/annotations/21069.png
# saved-test
# img 22071.jpg
# annotation_file /content/waterPuddle/annotations/3/22071_0.png
# label_path /content/waterPuddle/annotations/3/22071_0.png
# only one mask
# img 22071
# img_path /content/test/imgs/22071.jpg
# annotations_path /content/test/annotations/22071.png
# saved-test
# img 27095.jpg
# annotation_file /content/waterPuddle/annotations/3/27095_0.png
# label_path /content/waterPuddle/annotations/3/27095_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/27095_1.png
# img 27095
# img_path /content/test/imgs/27095.jpg
# annotations_path /content/test/annotations/27095.png
# saved-test
# img 24071.jpg
# annotation_file /content/waterPuddle/annotations/3/24071_0.png
# label_path /content/waterPuddle/annotations/3/24071_0.png
# only one mask
# img 24071
# img_path /content/test/imgs/24071.jpg
# annotations_path /content/test/annotations/24071.png
# saved-test
# img 21083.jpg
# annotation_file /content/waterPuddle/annotations/3/21083_0.png
# label_path /content/waterPuddle/annotations/3/21083_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/21083_1.png
# img 21083
# img_path /content/test/imgs/21083.jpg
# annotations_path /content/test/annotations/21083.png
# saved-test
# img 28085.jpg
# annotation_file /content/waterPuddle/annotations/3/28085_0.png
# img 320100.jpg
# annotation_file /content/waterPuddle/annotations/3/320100_0.png
# label_path /content/waterPuddle/annotations/3/320100_0.png
# only one mask
# img 320100
# img_path /content/test/imgs/320100.jpg
# annotations_path /content/test/annotations/320100.png
# saved-test
# img 24077.jpg
# annotation_file /content/waterPuddle/annotations/3/24077_0.png
# label_path /content/waterPuddle/annotations/3/24077_0.png
# only one mask
# img 24077
# img_path /content/test/imgs/24077.jpg
# annotations_path /content/test/annotations/24077.png
# saved-test
# img 3067.jpg
# annotation_file /content/waterPuddle/annotations/3/3067_0.png
# label_path /content/waterPuddle/annotations/3/3067_0.png
# only one mask
# img 3067
# img_path /content/test/imgs/3067.jpg
# annotations_path /content/test/annotations/3067.png
# saved-test
# img 26069.jpg
# annotation_file /content/waterPuddle/annotations/3/26069_0.png
# label_path /content/waterPuddle/annotations/3/26069_0.png
# only one mask
# img 26069
# img_path /content/test/imgs/26069.jpg
# annotations_path /content/test/annotations/26069.png
# saved-test
# img 34095.jpg
# annotation_file /content/waterPuddle/annotations/3/34095_0.png
# label_path /content/waterPuddle/annotations/3/34095_0.png
# only one mask
# img 34095
# img_path /content/test/imgs/34095.jpg
# annotations_path /content/test/annotations/34095.png
# saved-test
# img 23083.jpg
# annotation_file /content/waterPuddle/annotations/3/23083_0.png
# label_path /content/waterPuddle/annotations/3/23083_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/23083_1.png
# img 23083
# img_path /content/test/imgs/23083.jpg
# annotations_path /content/test/annotations/23083.png
# saved-test
# img 300106.jpg
# annotation_file /content/waterPuddle/annotations/3/300106_0.png
# img 26056.jpg
# annotation_file /content/waterPuddle/annotations/3/26056_0.png
# label_path /content/waterPuddle/annotations/3/26056_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/26056_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/3/26056_2.png
# img 26056
# img_path /content/test/imgs/26056.jpg
# annotations_path /content/test/annotations/26056.png
# saved-test
# img 26034.jpg
# annotation_file /content/waterPuddle/annotations/3/26034_0.png
# label_path /content/waterPuddle/annotations/3/26034_0.png
# only one mask
# img 26034
# img_path /content/test/imgs/26034.jpg
# annotations_path /content/test/annotations/26034.png
# saved-test
# img 260107.jpg
# annotation_file /content/waterPuddle/annotations/3/260107_0.png
# img 26035.jpg
# annotation_file /content/waterPuddle/annotations/3/26035_0.png
# label_path /content/waterPuddle/annotations/3/26035_0.png
# only one mask
# img 26035
# img_path /content/test/imgs/26035.jpg
# annotations_path /content/test/annotations/26035.png
# saved-test
# img 32076.jpg
# annotation_file /content/waterPuddle/annotations/3/32076_0.png
# label_path /content/waterPuddle/annotations/3/32076_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/32076_1.png
# img 32076
# img_path /content/test/imgs/32076.jpg
# annotations_path /content/test/annotations/32076.png
# saved-test
# img 25023.jpg
# annotation_file /content/waterPuddle/annotations/3/25023_0.png
# label_path /content/waterPuddle/annotations/3/25023_0.png
# only one mask
# img 25023
# img_path /content/test/imgs/25023.jpg
# annotations_path /content/test/annotations/25023.png
# saved-test
# img 23095.jpg
# annotation_file /content/waterPuddle/annotations/3/23095_0.png
# label_path /content/waterPuddle/annotations/3/23095_0.png
# only one mask
# img 23095
# img_path /content/test/imgs/23095.jpg
# annotations_path /content/test/annotations/23095.png
# saved-test
# img 23026.jpg
# annotation_file /content/waterPuddle/annotations/3/23026_0.png
# label_path /content/waterPuddle/annotations/3/23026_0.png
# only one mask
# img 23026
# img_path /content/test/imgs/23026.jpg
# annotations_path /content/test/annotations/23026.png
# saved-test
# img 23028.jpg
# annotation_file /content/waterPuddle/annotations/3/23028_0.png
# label_path /content/waterPuddle/annotations/3/23028_0.png
# only one mask
# img 23028
# img_path /content/test/imgs/23028.jpg
# annotations_path /content/test/annotations/23028.png
# saved-test
# img 30105.jpg
# annotation_file /content/waterPuddle/annotations/3/30105_0.png
# label_path /content/waterPuddle/annotations/3/30105_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/30105_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/3/30105_2.png
# img 30105
# img_path /content/test/imgs/30105.jpg
# annotations_path /content/test/annotations/30105.png
# saved-test
# img 28056.jpg
# annotation_file /content/waterPuddle/annotations/3/28056_0.png
# label_path /content/waterPuddle/annotations/3/28056_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/28056_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/3/28056_2.png
# img 28056
# img_path /content/test/imgs/28056.jpg
# annotations_path /content/test/annotations/28056.png
# saved-test
# img 25093.jpg
# annotation_file /content/waterPuddle/annotations/3/25093_0.png
# label_path /content/waterPuddle/annotations/3/25093_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/25093_1.png
# img 25093
# img_path /content/test/imgs/25093.jpg
# annotations_path /content/test/annotations/25093.png
# saved-test
# img 27094.jpg
# annotation_file /content/waterPuddle/annotations/3/27094_0.png
# label_path /content/waterPuddle/annotations/3/27094_0.png
# only one mask
# img 27094
# img_path /content/test/imgs/27094.jpg
# annotations_path /content/test/annotations/27094.png
# saved-test
# img 300108.jpg
# annotation_file /content/waterPuddle/annotations/3/300108_0.png
# label_path /content/waterPuddle/annotations/3/300108_0.png
# only one mask
# img 300108
# img_path /content/test/imgs/300108.jpg
# annotations_path /content/test/annotations/300108.png
# saved-test
# img 3057.jpg
# annotation_file /content/waterPuddle/annotations/3/3057_0.png
# label_path /content/waterPuddle/annotations/3/3057_0.png
# only one mask
# img 3057
# img_path /content/test/imgs/3057.jpg
# annotations_path /content/test/annotations/3057.png
# saved-test
# img 23056.jpg
# annotation_file /content/waterPuddle/annotations/3/23056_0.png
# label_path /content/waterPuddle/annotations/3/23056_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/23056_1.png
# img 23056
# img_path /content/test/imgs/23056.jpg
# annotations_path /content/test/annotations/23056.png
# saved-test
# img 27025.jpg
# annotation_file /content/waterPuddle/annotations/3/27025_0.png
# label_path /content/waterPuddle/annotations/3/27025_0.png
# only one mask
# img 27025
# img_path /content/test/imgs/27025.jpg
# annotations_path /content/test/annotations/27025.png
# saved-test
# img 32028.jpg
# annotation_file /content/waterPuddle/annotations/3/32028_0.png
# label_path /content/waterPuddle/annotations/3/32028_0.png
# only one mask
# img 32028
# img_path /content/test/imgs/32028.jpg
# annotations_path /content/test/annotations/32028.png
# saved-test
# img 27090.jpg
# annotation_file /content/waterPuddle/annotations/3/27090_0.png
# label_path /content/waterPuddle/annotations/3/27090_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/27090_1.png
# img 27090
# img_path /content/test/imgs/27090.jpg
# annotations_path /content/test/annotations/27090.png
# saved-test
# img 24086.jpg
# annotation_file /content/waterPuddle/annotations/3/24086_0.png
# label_path /content/waterPuddle/annotations/3/24086_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/24086_1.png
# img 24086
# img_path /content/test/imgs/24086.jpg
# annotations_path /content/test/annotations/24086.png
# saved-test
# img 3205.jpg
# annotation_file /content/waterPuddle/annotations/3/3205_0.png
# label_path /content/waterPuddle/annotations/3/3205_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/3205_1.png
# img 3205
# img_path /content/test/imgs/3205.jpg
# annotations_path /content/test/annotations/3205.png
# saved-test
# img 27076.jpg
# annotation_file /content/waterPuddle/annotations/3/27076_0.png
# label_path /content/waterPuddle/annotations/3/27076_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/27076_1.png
# img 27076
# img_path /content/test/imgs/27076.jpg
# annotations_path /content/test/annotations/27076.png
# saved-test
# img 250106.jpg
# annotation_file /content/waterPuddle/annotations/3/250106_0.png
# img 23025.jpg
# annotation_file /content/waterPuddle/annotations/3/23025_0.png
# img 28023.jpg
# annotation_file /content/waterPuddle/annotations/3/28023_0.png
# label_path /content/waterPuddle/annotations/3/28023_0.png
# only one mask
# img 28023
# img_path /content/test/imgs/28023.jpg
# annotations_path /content/test/annotations/28023.png
# saved-test
# img 34094.jpg
# annotation_file /content/waterPuddle/annotations/3/34094_0.png
# label_path /content/waterPuddle/annotations/3/34094_0.png
# only one mask
# img 34094
# img_path /content/test/imgs/34094.jpg
# annotations_path /content/test/annotations/34094.png
# saved-test
# img 32064.jpg
# annotation_file /content/waterPuddle/annotations/3/32064_0.png
# img 29069.jpg
# annotation_file /content/waterPuddle/annotations/3/29069_0.png
# label_path /content/waterPuddle/annotations/3/29069_0.png
# only one mask
# img 29069
# img_path /content/test/imgs/29069.jpg
# annotations_path /content/test/annotations/29069.png
# saved-test
# img 22092.jpg
# annotation_file /content/waterPuddle/annotations/3/22092_0.png
# img 27075.jpg
# annotation_file /content/waterPuddle/annotations/3/27075_0.png
# label_path /content/waterPuddle/annotations/3/27075_0.png
# only one mask
# img 27075
# img_path /content/test/imgs/27075.jpg
# annotations_path /content/test/annotations/27075.png
# saved-test
# img 23052.jpg
# annotation_file /content/waterPuddle/annotations/3/23052_0.png
# label_path /content/waterPuddle/annotations/3/23052_0.png
# only one mask
# img 23052
# img_path /content/test/imgs/23052.jpg
# annotations_path /content/test/annotations/23052.png
# saved-test
# img 3085.jpg
# annotation_file /content/waterPuddle/annotations/3/3085_0.png
# label_path /content/waterPuddle/annotations/3/3085_0.png
# only one mask
# img 3085
# img_path /content/test/imgs/3085.jpg
# annotations_path /content/test/annotations/3085.png
# saved-test
# img 27092.jpg
# annotation_file /content/waterPuddle/annotations/3/27092_0.png
# label_path /content/waterPuddle/annotations/3/27092_0.png
# only one mask
# img 27092
# img_path /content/test/imgs/27092.jpg
# annotations_path /content/test/annotations/27092.png
# saved-test
# img 29086.jpg
# annotation_file /content/waterPuddle/annotations/3/29086_0.png
# label_path /content/waterPuddle/annotations/3/29086_0.png
# only one mask
# img 29086
# img_path /content/test/imgs/29086.jpg
# annotations_path /content/test/annotations/29086.png
# saved-test
# img 3044.jpg
# annotation_file /content/waterPuddle/annotations/3/3044_0.png
# label_path /content/waterPuddle/annotations/3/3044_0.png
# only one mask
# img 3044
# img_path /content/test/imgs/3044.jpg
# annotations_path /content/test/annotations/3044.png
# saved-test
# img 22060.jpg
# annotation_file /content/waterPuddle/annotations/3/22060_0.png
# label_path /content/waterPuddle/annotations/3/22060_0.png
# only one mask
# img 22060
# img_path /content/test/imgs/22060.jpg
# annotations_path /content/test/annotations/22060.png
# saved-test
# img 26093.jpg
# annotation_file /content/waterPuddle/annotations/3/26093_0.png
# label_path /content/waterPuddle/annotations/3/26093_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/26093_1.png
# img 26093
# img_path /content/test/imgs/26093.jpg
# annotations_path /content/test/annotations/26093.png
# saved-test
# img 320111.jpg
# annotation_file /content/waterPuddle/annotations/3/320111_0.png
# label_path /content/waterPuddle/annotations/3/320111_0.png
# only one mask
# img 320111
# img_path /content/test/imgs/320111.jpg
# annotations_path /content/test/annotations/320111.png
# saved-test
# img 301.jpg
# annotation_file /content/waterPuddle/annotations/3/301_0.png
# img 24060.jpg
# annotation_file /content/waterPuddle/annotations/3/24060_0.png
# img 3099.jpg
# annotation_file /content/waterPuddle/annotations/3/3099_0.png
# label_path /content/waterPuddle/annotations/3/3099_0.png
# only one mask
# img 3099
# img_path /content/test/imgs/3099.jpg
# annotations_path /content/test/annotations/3099.png
# saved-test
# img 3068.jpg
# annotation_file /content/waterPuddle/annotations/3/3068_0.png
# label_path /content/waterPuddle/annotations/3/3068_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/3068_1.png
# img 3068
# img_path /content/test/imgs/3068.jpg
# annotations_path /content/test/annotations/3068.png
# saved-test
# img 280108.jpg
# annotation_file /content/waterPuddle/annotations/3/280108_0.png
# img 28075.jpg
# annotation_file /content/waterPuddle/annotations/3/28075_0.png
# img 33077.jpg
# annotation_file /content/waterPuddle/annotations/3/33077_0.png
# img 34034.jpg
# annotation_file /content/waterPuddle/annotations/3/34034_0.png
# label_path /content/waterPuddle/annotations/3/34034_0.png
# first mask
# label_path /content/waterPuddle/annotations/3/34034_1.png
# 1th mask
# label_path /content/waterPuddle/annotations/3/34034_2.png
# 2th mask
# label_path /content/waterPuddle/annotations/3/34034_3.png
# img 34034
# img_path /content/test/imgs/34034.jpg
# annotations_path /content/test/annotations/34034.png
# saved-test

# %%
img_height, img_width = 128, 128
batch_size = 32
num_epochs = 30

class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None, mask_transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform
        self.mask_transform = mask_transform

        self.images = sorted([f for f in os.listdir(image_dir)
                            if f.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))])

        # Verify that masks exist for all images
        self.valid_images = []
        for img in self.images:
            # Check if corresponding mask exists (might have different extension)
            base_name = os.path.splitext(img)[0]
            mask_exists = any(os.path.exists(os.path.join(mask_dir, base_name + ext))
                            for ext in ['.png', '.jpg', '.jpeg', '.bmp', '.tiff'])
            if mask_exists:
                self.valid_images.append(img)
            else:
                print(f"Warning: No mask found for image {img}")

        self.images = self.valid_images
        print(f"Found {len(self.images)} valid image-mask pairs")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Load image
        img_name = self.images[idx]
        img_path = os.path.join(self.image_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        # Load mask - try different extensions
        base_name = os.path.splitext(img_name)[0]
        mask = None
        for ext in ['.png', '.jpg', '.jpeg', '.bmp', '.tiff']:
            mask_path = os.path.join(self.mask_dir, base_name + ext)
            if os.path.exists(mask_path):
                mask = Image.open(mask_path).convert('L')  # Convert to grayscale
                break

        if mask is None:
            raise FileNotFoundError(f"Mask not found for {img_name}")

        # Apply transforms
        if self.transform:
            image = self.transform(image)
        if self.mask_transform:
            mask = self.mask_transform(mask)

        return image, mask

image_transform = transforms.Compose([
    transforms.Resize((img_height, img_width)),
    transforms.ToTensor(),  # Converts PIL to tensor and scales to [0, 1]
])

mask_transform = transforms.Compose([
    transforms.Resize((img_height, img_width)),
    transforms.ToTensor(),
])

print("Loading training dataset...")
train_dataset = SegmentationDataset(
    image_dir=os.path.join(train_path, 'imgs'),
    mask_dir=os.path.join(train_path, 'annotations'),
    transform=image_transform,
    mask_transform=mask_transform
)

print("\nLoading test dataset...")
test_dataset = SegmentationDataset(
    image_dir=os.path.join(test_path, 'imgs'),
    mask_dir=os.path.join(test_path, 'annotations'),
    transform=image_transform,
    mask_transform=mask_transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # Shuffle training data
    num_workers=8,  # Parallel data loading
    pin_memory=True if torch.cuda.is_available() else False,
    drop_last=False  # Don't drop the last incomplete batch
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # Don't shuffle test data
    num_workers=8,
    pin_memory=True if torch.cuda.is_available() else False,
    drop_last=False
)

print(f"\nTraining batches: {len(train_loader)}")
print(f"Test batches: {len(test_loader)}")

if len(train_loader) > 0:
    images, masks = next(iter(train_loader))
    print(f"\nSample batch shape:")
    print(f"Images: {images.shape} (dtype: {images.dtype}, range: [{images.min():.3f}, {images.max():.3f}])")
    print(f"Masks: {masks.shape} (dtype: {masks.dtype}, range: [{masks.min():.3f}, {masks.max():.3f}])")
# Out:
# Loading training dataset...
# Found 2308 valid image-mask pairs
#
# Loading test dataset...
# Found 567 valid image-mask pairs
#
# Training batches: 73
# Test batches: 18
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Sample batch shape:
# Images: torch.Size([32, 3, 128, 128]) (dtype: torch.float32, range: [0.000, 1.000])
# Masks: torch.Size([32, 1, 128, 128]) (dtype: torch.float32, range: [0.000, 1.000])

# %%
import torch
import torch.nn.functional as F

def iou(y_true, y_pred, smooth=100):
    """
    Calculate IoU using the same formula as Keras implementation.
    Note: This uses squared values in denominator which is non-standard for IoU.
    """
    # Ensure float tensors
    y_true = y_true.float()
    y_pred = y_pred.float()

    # Calculate intersection
    intersection = torch.sum(torch.abs(y_true * y_pred), dim=-1)

    # Calculate sum of squares
    sum_ = torch.sum(torch.square(y_true), dim=-1) + torch.sum(torch.square(y_pred), dim=-1)

    # Calculate IoU
    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    return jac

def dice_coef(y_true, y_pred, smooth=100):
    """
    Calculate Dice coefficient exactly as in Keras implementation.
    """
    # Flatten the tensors
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()

    # Calculate intersection
    intersection = torch.sum(y_true_f * y_pred_f)

    # Calculate Dice coefficient
    return (2. * intersection + smooth) / (torch.sum(y_true_f) + torch.sum(y_pred_f) + smooth)

def precision(y_true, y_pred):
    """
    Calculate precision exactly as in Keras implementation.
    """
    # Clip values between 0 and 1, then round
    true_positives = torch.sum(torch.round(torch.clamp(y_true * y_pred, 0, 1)))
    predicted_positives = torch.sum(torch.round(torch.clamp(y_pred, 0, 1)))

    # Calculate precision with epsilon to avoid division by zero
    precision_value = true_positives / (predicted_positives + 1e-7)

    return precision_value

def recall(y_true, y_pred):
    """
    Calculate recall exactly as in Keras implementation.
    """
    # Clip values between 0 and 1, then round
    true_positives = torch.sum(torch.round(torch.clamp(y_true * y_pred, 0, 1)))
    possible_positives = torch.sum(torch.round(torch.clamp(y_true, 0, 1)))

    # Calculate recall with epsilon to avoid division by zero
    recall_value = true_positives / (possible_positives + 1e-7)

    return recall_value

def accuracy(y_true, y_pred):
    """
    Calculate accuracy exactly as in Keras implementation.
    """
    # Round predictions and compare with true values
    return torch.mean((y_true == torch.round(y_pred)).float())

def jaccard_distance(y_true, y_pred, smooth=100):
    """
    Calculate Jaccard distance (1 - IoU) exactly as in Keras implementation.
    """
    # Cast to float32
    y_true = y_true.float()
    y_pred = y_pred.float()

    # Calculate intersection
    intersection = torch.sum(torch.abs(y_true * y_pred), dim=-1)

    # Calculate sum of squares
    sum_ = torch.sum(torch.square(y_true), dim=-1) + torch.sum(torch.square(y_pred), dim=-1)

    # Calculate Jaccard index
    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    # Return Jaccard distance
    return 1 - jac

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

class SegNet(nn.Module):
    def __init__(self, num_classes=1, input_channels=3):
        super(SegNet, self).__init__()

        # Encoder
        self.encoder1 = nn.Sequential(
            nn.Conv2d(input_channels, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.pool1 = nn.MaxPool2d(2, stride=2, return_indices=True)

        self.encoder2 = nn.Sequential(
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True)
        )
        self.pool2 = nn.MaxPool2d(2, stride=2, return_indices=True)

        self.encoder3 = nn.Sequential(
            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
        )
        self.pool3 = nn.MaxPool2d(2, stride=2, return_indices=True)

        self.encoder4 = nn.Sequential(
            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )
        self.pool4 = nn.MaxPool2d(2, stride=2, return_indices=True)

        self.encoder5 = nn.Sequential(
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )
        self.pool5 = nn.MaxPool2d(2, stride=2, return_indices=True)

        # Decoder
        self.unpool5 = nn.MaxUnpool2d(2, stride=2)
        self.decoder5 = nn.Sequential(
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        self.unpool4 = nn.MaxUnpool2d(2, stride=2)
        self.decoder4 = nn.Sequential(
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
        )

        self.unpool3 = nn.MaxUnpool2d(2, stride=2)
        self.decoder3 = nn.Sequential(
            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True)
        )

        self.unpool2 = nn.MaxUnpool2d(2, stride=2)
        self.decoder2 = nn.Sequential(
            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )

        self.unpool1 = nn.MaxUnpool2d(2, stride=2)
        self.decoder1 = nn.Sequential(
            nn.Conv2d(64, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, num_classes, 3, padding=1)
        )

    def forward(self, x):
        # Encoder
        x = self.encoder1(x)
        x, indices1 = self.pool1(x)

        x = self.encoder2(x)
        x, indices2 = self.pool2(x)

        x = self.encoder3(x)
        x, indices3 = self.pool3(x)

        x = self.encoder4(x)
        x, indices4 = self.pool4(x)

        x = self.encoder5(x)
        x, indices5 = self.pool5(x)

        # Decoder
        x = self.unpool5(x, indices5)
        x = self.decoder5(x)

        x = self.unpool4(x, indices4)
        x = self.decoder4(x)

        x = self.unpool3(x, indices3)
        x = self.decoder3(x)

        x = self.unpool2(x, indices2)
        x = self.decoder2(x)

        x = self.unpool1(x, indices1)
        x = self.decoder1(x)

        return torch.sigmoid(x)


modelName = "SegNet"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize SegNet model
model = SegNet(num_classes=1, input_channels=3).to(device)

criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

print(f"Model has {sum(p.numel() for p in model.parameters() if p.requires_grad):,} trainable parameters")

# Function to calculate all metrics
def calculate_all_metrics(y_true, y_pred):
    """Calculate all metrics for a batch"""
    metrics = {}

    # Convert to binary predictions
    y_pred_binary = (y_pred > 0.5).float()

    # Calculate each metric
    metrics['iou'] = iou(y_true, y_pred_binary).mean().item()
    metrics['dice'] = dice_coef(y_true, y_pred_binary).item()
    metrics['precision'] = precision(y_true, y_pred_binary).item()
    metrics['recall'] = recall(y_true, y_pred_binary).item()
    metrics['accuracy'] = accuracy(y_true, y_pred_binary).item()
    metrics['jaccard_distance'] = jaccard_distance(y_true, y_pred_binary).mean().item()

    return metrics

def validate_model():
    """Comprehensive validation with all metrics"""
    model.eval()

    # Initialize metric accumulators
    total_metrics = {
        'iou': 0,
        'dice': 0,
        'precision': 0,
        'recall': 0,
        'accuracy': 0,
        'jaccard_distance': 0,
        'loss': 0
    }

    num_batches = 0

    with torch.no_grad():
        for images, masks in test_loader:
            images = images.to(device)
            masks = masks.to(device)

            # Forward pass
            outputs = model(images)

            # Calculate loss
            loss = criterion(outputs, masks)
            total_metrics['loss'] += loss.item()

            # Calculate all metrics
            batch_metrics = calculate_all_metrics(masks, outputs)

            # Accumulate metrics
            for key, value in batch_metrics.items():
                total_metrics[key] += value

            num_batches += 1

    # Calculate averages
    avg_metrics = {key: value / num_batches for key, value in total_metrics.items()}

    # Print results
    print("\n" + "="*50)
    print("VALIDATION RESULTS:")
    print("="*50)
    print(f"Loss:              {avg_metrics['loss']:.4f}")
    print(f"IoU:               {avg_metrics['iou']:.4f}")
    print(f"Dice Coefficient:  {avg_metrics['dice']:.4f}")
    print(f"Precision:         {avg_metrics['precision']:.4f}")
    print(f"Recall:            {avg_metrics['recall']:.4f}")
    print(f"Accuracy:          {avg_metrics['accuracy']:.4f}")
    print(f"Jaccard Distance:  {avg_metrics['jaccard_distance']:.4f}")
    print("="*50 + "\n")

    model.train()
    return avg_metrics

def train_model():
    """Training loop with comprehensive metric tracking"""
    best_dice = 0.0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        epoch_metrics = {
            'iou': 0,
            'dice': 0,
            'precision': 0,
            'recall': 0,
            'accuracy': 0,
            'jaccard_distance': 0
        }

        print(f"\nEpoch {epoch+1}/{num_epochs}")
        print("-" * 30)

        for batch_idx, (images, masks) in enumerate(train_loader):
            images = images.to(device)
            masks = masks.to(device)

            # Zero gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, masks)

            # Backward pass
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Calculate metrics for this batch
            with torch.no_grad():
                batch_metrics = calculate_all_metrics(masks, outputs)
                for key, value in batch_metrics.items():
                    epoch_metrics[key] += value

            # Print progress every 20 batches
            if batch_idx % 20 == 0:
                print(f'Batch {batch_idx:3d}/{len(train_loader)} | Loss: {loss.item():.4f} | '
                      f'IoU: {batch_metrics["iou"]:.3f} | Dice: {batch_metrics["dice"]:.3f}')

        # Calculate epoch averages
        avg_loss = running_loss / len(train_loader)
        avg_epoch_metrics = {key: value / len(train_loader) for key, value in epoch_metrics.items()}

        print(f'\nEpoch {epoch+1} Training Results:')
        print(f'Average Loss: {avg_loss:.4f}')
        print(f'Average IoU: {avg_epoch_metrics["iou"]:.4f}')
        print(f'Average Dice: {avg_epoch_metrics["dice"]:.4f}')
        print(f'Average Precision: {avg_epoch_metrics["precision"]:.4f}')
        print(f'Average Recall: {avg_epoch_metrics["recall"]:.4f}')
        print(f'Average Accuracy: {avg_epoch_metrics["accuracy"]:.4f}')

        # Validation every 2 epochs
        if epoch % 2 == 0 or epoch == num_epochs - 1:
            val_metrics = validate_model()

            # Save best model based on Dice score
            if val_metrics['dice'] > best_dice:
                best_dice = val_metrics['dice']
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'dice_score': best_dice,
                    'all_metrics': val_metrics
                }, 'best_model.pth')
                print(f"✓ New best model saved with Dice score: {best_dice:.4f}")

import json
import os

def save_metrics(model_name, metrics, file_path="model_metrics.json"):
    """Save evaluation metrics to a JSON file."""
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            all_metrics = json.load(f)
    else:
        all_metrics = {}

    all_metrics[model_name] = metrics

    with open(file_path, 'w') as f:
        json.dump(all_metrics, f, indent=4)

    print(f"✓ Metrics for {model_name} saved to {file_path}")


def evaluate_final_model():
    """Final comprehensive evaluation"""
    print("\n" + "="*60)
    print("FINAL MODEL EVALUATION")
    print("="*60)

    # Load best model if it exists
    try:
        checkpoint = torch.load('best_model.pth')
        model.load_state_dict(checkpoint['model_state_dict'])
        print(f"Loaded best model from epoch {checkpoint['epoch']} with Dice: {checkpoint['dice_score']:.4f}")
    except:
        print("Using current model weights for evaluation")

    # Run final validation
    final_metrics = validate_model()
    save_metrics(modelName, final_metrics)

    return final_metrics

def load_metrics(file_path="model_metrics.json"):
    with open(file_path, 'r') as f:
        return json.load(f)


# Start training
if __name__ == "__main__":
    print("Starting training Segnet with comprehensive metrics...")
    train_model()

    # Final evaluation
    final_results = evaluate_final_model()

    print("\nTraining completed!")
    print(f"Final Results Summary:")
    for metric, value in final_results.items():
        print(f"{metric.capitalize()}: {value:.4f}")

    metrics_dict = load_metrics()
    print(metrics_dict)
# Out:
# Model has 29,443,585 trainable parameters
# Starting training Segnet with comprehensive metrics...
#
# Epoch 1/30
# ------------------------------
# Batch   0/73 | Loss: 0.6762 | IoU: 0.663 | Dice: 0.154
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2187274626.py in <cell line: 0>()
#     594 if __name__ == "__main__":
#     595     print("Starting training Segnet with comprehensive metrics...")
# --> 596     train_model()
#     597
#     598     # Final evaluation
#
# /tmp/ipython-input-2187274626.py in train_model()
#     503
#     504             # Backward pass
# --> 505             loss.backward()
#     506             optimizer.step()
#     507
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     827         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828     try:
# --> 829         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830             t_outputs, *args, **kwargs
#     831         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
import torch
import json
import os
from datetime import datetime

def test_model(model, test_loader, device, model_path=None, save_results=True):
    """Comprehensive testing with all metrics and detailed analysis"""

    # Load model if path provided
    if model_path and os.path.exists(model_path):
        checkpoint = torch.load(model_path, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        print(f"✓ Loaded model from {model_path}")
        if 'epoch' in checkpoint:
            print(f"  Model was saved at epoch {checkpoint['epoch']}")
        if 'dice_score' in checkpoint:
            print(f"  Training Dice score: {checkpoint['dice_score']:.4f}")
    else:
        print("Using current model weights for testing")

    model.eval()

    # Initialize metric accumulators
    total_metrics = {
        'iou': 0,
        'dice': 0,
        'precision': 0,
        'recall': 0,
        'accuracy': 0,
        'jaccard_distance': 0,
        'loss': 0
    }

    # For per-batch analysis
    batch_metrics = []
    num_batches = 0
    total_samples = 0

    # Loss function for testing
    criterion = torch.nn.BCELoss()

    print("\n" + "="*60)
    print("RUNNING COMPREHENSIVE TEST EVALUATION")
    print("="*60)

    with torch.no_grad():
        for batch_idx, (images, masks) in enumerate(test_loader):
            images = images.to(device)
            masks = masks.to(device)
            batch_size = images.size(0)
            total_samples += batch_size

            # Forward pass
            outputs = model(images)

            # Calculate loss
            loss = criterion(outputs, masks)
            total_metrics['loss'] += loss.item()

            # Calculate all metrics for this batch
            batch_metric_values = calculate_all_metrics(masks, outputs)
            batch_metric_values['loss'] = loss.item()
            batch_metric_values['batch_size'] = batch_size
            batch_metrics.append(batch_metric_values)

            # Accumulate metrics
            for key, value in batch_metric_values.items():
                if key not in ['batch_size']:
                    total_metrics[key] += value

            num_batches += 1

            # Print progress every 5 batches
            if batch_idx % 5 == 0:
                print(f"Processed batch {batch_idx+1}/{len(test_loader)} "
                      f"({total_samples} samples) | "
                      f"IoU: {batch_metric_values['iou']:.3f} | "
                      f"Dice: {batch_metric_values['dice']:.3f}")

    # Calculate final averages
    avg_metrics = {key: value / num_batches for key, value in total_metrics.items()}

    # Calculate standard deviations
    std_metrics = {}
    for metric in ['iou', 'dice', 'precision', 'recall', 'accuracy', 'jaccard_distance', 'loss']:
        values = [batch[metric] for batch in batch_metrics]
        mean_val = sum(values) / len(values)
        variance = sum((x - mean_val) ** 2 for x in values) / len(values)
        std_metrics[metric] = variance ** 0.5

    # Print comprehensive test results
    print("\n" + "="*60)
    print("FINAL TEST RESULTS")
    print("="*60)
    print(f"Total test samples: {total_samples}")
    print(f"Total test batches: {num_batches}")
    print("-" * 60)
    print(f"{'Metric':<20} {'Mean':<10} {'Std':<10} {'Range'}")
    print("-" * 60)

    for metric in ['loss', 'iou', 'dice', 'precision', 'recall', 'accuracy', 'jaccard_distance']:
        values = [batch[metric] for batch in batch_metrics]
        min_val = min(values)
        max_val = max(values)
        print(f"{metric.capitalize():<20} {avg_metrics[metric]:<10.4f} {std_metrics[metric]:<10.4f} [{min_val:.3f}, {max_val:.3f}]")

    print("=" * 60)

    # Additional analysis
    print("\nDETAILED ANALYSIS:")
    print("-" * 30)

    # Best and worst performing batches
    dice_values = [batch['dice'] for batch in batch_metrics]
    best_batch_idx = dice_values.index(max(dice_values))
    worst_batch_idx = dice_values.index(min(dice_values))

    print(f"Best performing batch:  #{best_batch_idx+1} (Dice: {max(dice_values):.4f})")
    print(f"Worst performing batch: #{worst_batch_idx+1} (Dice: {min(dice_values):.4f})")

    # Performance distribution
    excellent = sum(1 for d in dice_values if d > 0.8)
    good = sum(1 for d in dice_values if 0.6 < d <= 0.8)
    fair = sum(1 for d in dice_values if 0.4 < d <= 0.6)
    poor = sum(1 for d in dice_values if d <= 0.4)

    print(f"\nPerformance distribution (by Dice score):")
    print(f"  Excellent (>0.8):     {excellent:3d} batches ({excellent/num_batches*100:.1f}%)")
    print(f"  Good (0.6-0.8):       {good:3d} batches ({good/num_batches*100:.1f}%)")
    print(f"  Fair (0.4-0.6):       {fair:3d} batches ({fair/num_batches*100:.1f}%)")
    print(f"  Poor (≤0.4):          {poor:3d} batches ({poor/num_batches*100:.1f}%)")

    # Save results if requested
    if save_results:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        results = {
            'timestamp': timestamp,
            'model_path': model_path,
            'total_samples': total_samples,
            'total_batches': num_batches,
            'average_metrics': avg_metrics,
            'std_metrics': std_metrics,
            'batch_metrics': batch_metrics,
            'performance_distribution': {
                'excellent': excellent,
                'good': good,
                'fair': fair,
                'poor': poor
            }
        }

        results_file = f'test_results_{timestamp}.json'
        with open(results_file, 'w') as f:
            json.dump(results, f, indent=2)
        print(f"\n✓ Test results saved to {results_file}")

    return avg_metrics, batch_metrics

def calculate_all_metrics(y_true, y_pred):
    """Calculate all metrics for a batch"""
    metrics = {}

    # Convert to binary predictions
    y_pred_binary = (y_pred > 0.5).float()

    # Calculate each metric using your defined functions
    metrics['iou'] = iou(y_true, y_pred_binary).mean().item()
    metrics['dice'] = dice_coef(y_true, y_pred_binary).item()
    metrics['precision'] = precision(y_true, y_pred_binary).item()
    metrics['recall'] = recall(y_true, y_pred_binary).item()
    metrics['accuracy'] = accuracy(y_true, y_pred_binary).item()
    metrics['jaccard_distance'] = jaccard_distance(y_true, y_pred_binary).mean().item()

    return metrics

# Simple test function without detailed analysis
def quick_test(model, test_loader, device):
    """Quick test with just average metrics"""
    model.eval()
    total_metrics = {
        'iou': 0, 'dice': 0, 'precision': 0,
        'recall': 0, 'accuracy': 0, 'jaccard_distance': 0
    }

    num_batches = 0
    with torch.no_grad():
        for images, masks in test_loader:
            images = images.to(device)
            masks = masks.to(device)
            outputs = model(images)

            batch_metrics = calculate_all_metrics(masks, outputs)
            for key, value in batch_metrics.items():
                total_metrics[key] += value
            num_batches += 1

    # Calculate averages
    avg_metrics = {key: value / num_batches for key, value in total_metrics.items()}

    print("Quick Test Results:")
    for metric, value in avg_metrics.items():
        print(f"{metric.capitalize()}: {value:.4f}")

    return avg_metrics

# Usage examples:
if __name__ == "__main__":
    # Assuming you have model, test_loader, and device defined

    # Method 1: Comprehensive test with saved model
    test_metrics, batch_results = test_model(
        model=model,
        test_loader=test_loader,
        device=device,
        model_path='best_model.pth',  # Path to your saved model
        save_results=True
    )

    # Method 2: Test current model without saving
    # test_metrics, batch_results = test_model(
    #     model=model,
    #     test_loader=test_loader,
    #     device=device,
    #     model_path=None,
    #     save_results=False
    # )

    # Method 3: Quick test (just averages)
    # quick_metrics = quick_test(model, test_loader, device)
